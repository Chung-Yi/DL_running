# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 1.15.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/gdrive/My Drive/D44
# [Errno 2] No such file or directory: 'cupoy_cv_part4 # 可以自己改路徑'
# /content/gdrive/My Drive/D44

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
cd D44
# Out:
# /content/gdrive/My Drive/D44

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
imgs_train
# Out:
# array([[[0.93333334, 0.9254902 , 0.92941177, ..., 0.98039216,
#          0.98039216, 0.98039216],
#         [0.92156863, 0.93333334, 0.9254902 , ..., 0.9764706 ,
#          0.98039216, 0.9843137 ],
#         [0.92941177, 0.9254902 , 0.92941177, ..., 0.9843137 ,
#          0.9843137 , 0.98039216],
#         ...,
#         [0.7294118 , 0.7176471 , 0.70980394, ..., 0.20392157,
#          0.22352941, 0.23529412],
#         [0.7411765 , 0.7372549 , 0.8117647 , ..., 0.23921569,
#          0.27058825, 0.30588236],
#         [0.7490196 , 0.72156864, 0.72156864, ..., 0.27450982,
#          0.29411766, 0.3529412 ]],
#
#        [[0.85882354, 0.84313726, 0.8       , ..., 0.36078432,
#          0.34509805, 0.32941177],
#         [0.87058824, 0.85882354, 0.8627451 , ..., 0.36078432,
#          0.34509805, 0.3372549 ],
#         [0.90588236, 0.8784314 , 0.83137256, ..., 0.3019608 ,
#          0.3137255 , 0.32941177],
#         ...,
#         [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157,
#          0.00392157, 0.00392157],
#         [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157,
#          0.00392157, 0.00392157],
#         [0.00392157, 0.00392157, 0.00392157, ..., 0.00392157,
#          0.00392157, 0.00392157]],
#
#        [[0.5647059 , 0.5568628 , 0.62352943, ..., 0.8156863 ,
#          0.8117647 , 0.8117647 ],
#         [0.56078434, 0.5568628 , 0.6313726 , ..., 0.8156863 ,
#          0.8156863 , 0.8117647 ],
#         [0.56078434, 0.54901963, 0.627451  , ..., 0.81960785,
#          0.81960785, 0.8117647 ],
#         ...,
#         [0.25882354, 0.27450982, 0.27058825, ..., 0.31764707,
#          0.5254902 , 0.7607843 ],
#         [0.25490198, 0.27058825, 0.2784314 , ..., 0.29411766,
#          0.3254902 , 0.42745098],
#         [0.25490198, 0.26666668, 0.27450982, ..., 0.30588236,
#          0.30588236, 0.3019608 ]],
#
#        ...,
#
#        [[0.12156863, 0.15686275, 0.18431373, ..., 0.7764706 ,
#          0.7764706 , 0.77254903],
#         [0.13725491, 0.18431373, 0.18039216, ..., 0.77254903,
#          0.78039217, 0.77254903],
#         [0.16862746, 0.20392157, 0.18039216, ..., 0.7647059 ,
#          0.7764706 , 0.7764706 ],
#         ...,
#         [0.5058824 , 0.5254902 , 0.5254902 , ..., 0.14509805,
#          0.15294118, 0.21568628],
#         [0.50980395, 0.53333336, 0.5372549 , ..., 0.14901961,
#          0.1764706 , 0.2509804 ],
#         [0.5019608 , 0.53333336, 0.5294118 , ..., 0.15294118,
#          0.2       , 0.29411766]],
#
#        [[0.02745098, 0.00392157, 0.01960784, ..., 0.03529412,
#          0.07843138, 0.14901961],
#         [0.        , 0.01176471, 0.03137255, ..., 0.03529412,
#          0.0627451 , 0.14117648],
#         [0.        , 0.03529412, 0.03137255, ..., 0.02352941,
#          0.03921569, 0.09803922],
#         ...,
#         [0.32156864, 0.3254902 , 0.3254902 , ..., 0.7019608 ,
#          0.6431373 , 0.14117648],
#         [0.32156864, 0.3254902 , 0.3254902 , ..., 0.69411767,
#          0.6745098 , 0.1764706 ],
#         [0.3254902 , 0.32941177, 0.32941177, ..., 0.7019608 ,
#          0.69411767, 0.22352941]],
#
#        [[0.26666668, 0.07450981, 0.07450981, ..., 0.01176471,
#          0.03137255, 0.01176471],
#         [0.27450982, 0.10588235, 0.06666667, ..., 0.01960784,
#          0.02745098, 0.01568628],
#         [0.35686275, 0.10196079, 0.0627451 , ..., 0.01960784,
#          0.03137255, 0.01960784],
#         ...,
#         [0.45490196, 0.4627451 , 0.48235294, ..., 0.4627451 ,
#          0.45490196, 0.45882353],
#         [0.45490196, 0.46666667, 0.49019608, ..., 0.47843137,
#          0.4745098 , 0.47058824],
#         [0.47058824, 0.4862745 , 0.5058824 , ..., 0.49019608,
#          0.4862745 , 0.46666667]]], dtype=float32)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0081 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00251, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 0.0021 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00251 to 0.00203, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00203 to 0.00189, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00189 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00184
# Epoch 6/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00184
# Epoch 7/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00007: val_loss did not improve from 0.00184
# Epoch 8/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.1223e-04 - val_loss: 0.0018
#
# Epoch 00008: val_loss improved from 0.00184 to 0.00181, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 8.2528e-04 - val_loss: 0.0017
#
# Epoch 00009: val_loss improved from 0.00181 to 0.00171, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 7.3453e-04 - val_loss: 0.0016
#
# Epoch 00010: val_loss improved from 0.00171 to 0.00156, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 6.6855e-04 - val_loss: 0.0015
#
# Epoch 00011: val_loss improved from 0.00156 to 0.00145, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 6.1814e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00145 to 0.00126, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 5.6928e-04 - val_loss: 0.0013
#
# Epoch 00013: val_loss did not improve from 0.00126
# Epoch 14/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 5.1777e-04 - val_loss: 0.0012
#
# Epoch 00014: val_loss improved from 0.00126 to 0.00121, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 4.7671e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00121 to 0.00112, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 4.5377e-04 - val_loss: 0.0011
#
# Epoch 00016: val_loss improved from 0.00112 to 0.00106, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 4.3174e-04 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00106
# Epoch 18/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 4.3358e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss improved from 0.00106 to 0.00101, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 4.0013e-04 - val_loss: 9.7834e-04
#
# Epoch 00019: val_loss improved from 0.00101 to 0.00098, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 3.7245e-04 - val_loss: 0.0010
#
# Epoch 00020: val_loss did not improve from 0.00098
# Epoch 21/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 3.6491e-04 - val_loss: 9.9701e-04
#
# Epoch 00021: val_loss did not improve from 0.00098
# Epoch 22/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 3.4365e-04 - val_loss: 9.0302e-04
#
# Epoch 00022: val_loss improved from 0.00098 to 0.00090, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 3.4669e-04 - val_loss: 9.0793e-04
#
# Epoch 00023: val_loss did not improve from 0.00090
# Epoch 24/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 3.1918e-04 - val_loss: 9.0052e-04
#
# Epoch 00024: val_loss improved from 0.00090 to 0.00090, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 3.1077e-04 - val_loss: 9.1504e-04
#
# Epoch 00025: val_loss did not improve from 0.00090
# Epoch 26/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 3.0383e-04 - val_loss: 8.8846e-04
#
# Epoch 00026: val_loss improved from 0.00090 to 0.00089, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 3.0485e-04 - val_loss: 8.5057e-04
#
# Epoch 00027: val_loss improved from 0.00089 to 0.00085, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 2.8828e-04 - val_loss: 8.7633e-04
#
# Epoch 00028: val_loss did not improve from 0.00085
# Epoch 29/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 2.7433e-04 - val_loss: 9.0699e-04
#
# Epoch 00029: val_loss did not improve from 0.00085
# Epoch 30/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 2.7387e-04 - val_loss: 8.4305e-04
#
# Epoch 00030: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 2.6523e-04 - val_loss: 8.7559e-04
#
# Epoch 00031: val_loss did not improve from 0.00084
# Epoch 32/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.6445e-04 - val_loss: 8.6427e-04
#
# Epoch 00032: val_loss did not improve from 0.00084
# Epoch 33/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.5296e-04 - val_loss: 8.5768e-04
#
# Epoch 00033: val_loss did not improve from 0.00084
# Epoch 34/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.5165e-04 - val_loss: 8.5127e-04
#
# Epoch 00034: val_loss did not improve from 0.00084
# Epoch 35/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.5134e-04 - val_loss: 8.2906e-04
#
# Epoch 00035: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.4367e-04 - val_loss: 8.0915e-04
#
# Epoch 00036: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 2.3716e-04 - val_loss: 8.6150e-04
#
# Epoch 00037: val_loss did not improve from 0.00081
# Epoch 38/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.3393e-04 - val_loss: 8.2474e-04
#
# Epoch 00038: val_loss did not improve from 0.00081
# Epoch 39/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 2.2590e-04 - val_loss: 8.4949e-04
#
# Epoch 00039: val_loss did not improve from 0.00081
# Epoch 40/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 2.2488e-04 - val_loss: 8.6502e-04
#
# Epoch 00040: val_loss did not improve from 0.00081
# Epoch 41/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.2155e-04 - val_loss: 8.2825e-04
#
# Epoch 00041: val_loss did not improve from 0.00081
# Epoch 42/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.1270e-04 - val_loss: 8.1657e-04
#
# Epoch 00042: val_loss did not improve from 0.00081
# Epoch 43/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.1799e-04 - val_loss: 8.4384e-04
#
# Epoch 00043: val_loss did not improve from 0.00081
# Epoch 44/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 2.1592e-04 - val_loss: 8.1682e-04
#
# Epoch 00044: val_loss did not improve from 0.00081
# Epoch 45/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.0709e-04 - val_loss: 8.3388e-04
#
# Epoch 00045: val_loss did not improve from 0.00081
# Epoch 46/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 2.0775e-04 - val_loss: 8.2961e-04
#
# Epoch 00046: val_loss did not improve from 0.00081
# Epoch 47/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.0622e-04 - val_loss: 8.0295e-04
#
# Epoch 00047: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 2.1249e-04 - val_loss: 8.2210e-04
#
# Epoch 00048: val_loss did not improve from 0.00080
# Epoch 49/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.9675e-04 - val_loss: 7.8795e-04
#
# Epoch 00049: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.9362e-04 - val_loss: 8.0161e-04
#
# Epoch 00050: val_loss did not improve from 0.00079
# Epoch 51/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.9059e-04 - val_loss: 7.8842e-04
#
# Epoch 00051: val_loss did not improve from 0.00079
# Epoch 52/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.9003e-04 - val_loss: 7.9317e-04
#
# Epoch 00052: val_loss did not improve from 0.00079
# Epoch 53/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.9772e-04 - val_loss: 8.4396e-04
#
# Epoch 00053: val_loss did not improve from 0.00079
# Epoch 54/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.8618e-04 - val_loss: 7.9490e-04
#
# Epoch 00054: val_loss did not improve from 0.00079
# Epoch 55/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.8253e-04 - val_loss: 7.8646e-04
#
# Epoch 00055: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.8504e-04 - val_loss: 8.0855e-04
#
# Epoch 00056: val_loss did not improve from 0.00079
# Epoch 57/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.7534e-04 - val_loss: 8.1627e-04
#
# Epoch 00057: val_loss did not improve from 0.00079
# Epoch 58/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.7897e-04 - val_loss: 8.1355e-04
#
# Epoch 00058: val_loss did not improve from 0.00079
# Epoch 59/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.7780e-04 - val_loss: 8.0461e-04
#
# Epoch 00059: val_loss did not improve from 0.00079
# Epoch 60/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.7817e-04 - val_loss: 8.1817e-04
#
# Epoch 00060: val_loss did not improve from 0.00079
# Epoch 61/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.7542e-04 - val_loss: 8.0273e-04
#
# Epoch 00061: val_loss did not improve from 0.00079
# Epoch 62/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.7669e-04 - val_loss: 7.7901e-04
#
# Epoch 00062: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 63/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.6638e-04 - val_loss: 8.2352e-04
#
# Epoch 00063: val_loss did not improve from 0.00078
# Epoch 64/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.6578e-04 - val_loss: 7.8315e-04
#
# Epoch 00064: val_loss did not improve from 0.00078
# Epoch 65/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.6576e-04 - val_loss: 7.7881e-04
#
# Epoch 00065: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.6611e-04 - val_loss: 7.4954e-04
#
# Epoch 00066: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 67/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.6243e-04 - val_loss: 7.9345e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.5730e-04 - val_loss: 8.5189e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.6137e-04 - val_loss: 7.8128e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5685e-04 - val_loss: 7.7160e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5732e-04 - val_loss: 7.7177e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.5782e-04 - val_loss: 7.7628e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.5209e-04 - val_loss: 7.6198e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.5309e-04 - val_loss: 7.8552e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.5006e-04 - val_loss: 8.1123e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.4959e-04 - val_loss: 7.8236e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.4517e-04 - val_loss: 8.3586e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.4825e-04 - val_loss: 7.6402e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.4602e-04 - val_loss: 7.8759e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.4689e-04 - val_loss: 7.6423e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.4471e-04 - val_loss: 7.8152e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.4517e-04 - val_loss: 7.6055e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.4310e-04 - val_loss: 8.0303e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.4155e-04 - val_loss: 7.7313e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.3909e-04 - val_loss: 7.6222e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.4378e-04 - val_loss: 7.9885e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.4191e-04 - val_loss: 7.8592e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3939e-04 - val_loss: 7.9614e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.3555e-04 - val_loss: 8.0720e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.3305e-04 - val_loss: 8.1352e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.2680e-04 - val_loss: 7.7949e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2630e-04 - val_loss: 8.2391e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.2853e-04 - val_loss: 7.8799e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2992e-04 - val_loss: 7.6409e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2908e-04 - val_loss: 7.8766e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
# Epoch 96/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2408e-04 - val_loss: 8.0281e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.2860e-04 - val_loss: 8.0674e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.2457e-04 - val_loss: 8.1424e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2634e-04 - val_loss: 7.7584e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2096e-04 - val_loss: 7.7117e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.2142e-04 - val_loss: 8.2038e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2135e-04 - val_loss: 7.8773e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.2493e-04 - val_loss: 8.0979e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.2414e-04 - val_loss: 7.7797e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1830e-04 - val_loss: 7.9964e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2043e-04 - val_loss: 7.9278e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.1742e-04 - val_loss: 7.9392e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.1624e-04 - val_loss: 7.7942e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1723e-04 - val_loss: 7.6893e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.1789e-04 - val_loss: 8.0505e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2226e-04 - val_loss: 7.9514e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.1352e-04 - val_loss: 8.0176e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1062e-04 - val_loss: 8.4655e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0993e-04 - val_loss: 7.8758e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0887e-04 - val_loss: 7.7709e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.0977e-04 - val_loss: 7.9308e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1080e-04 - val_loss: 7.8515e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1007e-04 - val_loss: 7.9525e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0891e-04 - val_loss: 7.7061e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.0896e-04 - val_loss: 7.7794e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.0644e-04 - val_loss: 7.9357e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0754e-04 - val_loss: 7.7805e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.0684e-04 - val_loss: 8.4210e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.0802e-04 - val_loss: 7.8742e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0556e-04 - val_loss: 8.0919e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0570e-04 - val_loss: 8.4243e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.0763e-04 - val_loss: 8.1169e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0571e-04 - val_loss: 8.2254e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.0164e-04 - val_loss: 8.1659e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.8333e-05 - val_loss: 7.8660e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0239e-04 - val_loss: 8.0246e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0077e-04 - val_loss: 8.2879e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.0012e-04 - val_loss: 7.8323e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.8479e-05 - val_loss: 7.8646e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 9.8026e-05 - val_loss: 7.6968e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 9.6245e-05 - val_loss: 7.9260e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.9296e-05 - val_loss: 8.0932e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.8253e-05 - val_loss: 8.3203e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.9572e-05 - val_loss: 8.0960e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 9.5499e-05 - val_loss: 8.0014e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 9.5471e-05 - val_loss: 7.8535e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.5117e-05 - val_loss: 7.9566e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.4050e-05 - val_loss: 7.9845e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.3673e-05 - val_loss: 8.0227e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.6029e-05 - val_loss: 7.9289e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.3448e-05 - val_loss: 7.7544e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.6038e-05 - val_loss: 8.0038e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.4107e-05 - val_loss: 7.8989e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.3274e-05 - val_loss: 8.1038e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 9.0500e-05 - val_loss: 7.8308e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0143199dd7d0> in <module>()
# ----> 1 model_with_augment = get_model()
#       2 model_with_augment.compile(loss='mean_squared_error', optimizer='adam')
#
# NameError: name 'get_model' is not defined

# %%
imgs_train.shape
# Out:
# (2140, 96, 96)

# %%
from imgaug import augmenters as iaa

# %%
# Your code


def augment_img(imgs_train, points_train):
  flipper = iaa.Fliplr(1.0)
  image_flip = flipper.augment_image(imgs_train[:])
  # for img in imgs_train:
  #   print(i.shape)
  #   break

augment_img(imgs_train, points_train)

# %%
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    # for i in range(96):
    #     for j in range(48):
    #         temp = img[i][j]
    #         new_img[i][j] = img[i][cols-j-1]
    #         new_img[i][cols-j-1] = temp
    flipper = iaa.Fliplr(1.0)
    new_img = flipper.augment_image(img)
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
model_augment = get_model()
model_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
checkpoint = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model_augment.fit(aug_imgs_train.reshape(-1, 96, 96, 1), 
                       aug_points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('augmeng_weights.h5')
# save the model
model.save('augment_model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 3424/3424 [==============================] - 3s 898us/step - loss: 0.0062 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00192, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 0.0015 - val_loss: 0.0021
#
# Epoch 00002: val_loss did not improve from 0.00192
# Epoch 3/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00192 to 0.00185, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00004: val_loss improved from 0.00185 to 0.00172, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 8.0720e-04 - val_loss: 0.0014
#
# Epoch 00005: val_loss improved from 0.00172 to 0.00144, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 6.5442e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00144 to 0.00117, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 5.6264e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00117 to 0.00108, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 195us/step - loss: 5.0434e-04 - val_loss: 0.0011
#
# Epoch 00008: val_loss improved from 0.00108 to 0.00105, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 4.4325e-04 - val_loss: 9.4573e-04
#
# Epoch 00009: val_loss improved from 0.00105 to 0.00095, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 4.3224e-04 - val_loss: 8.6820e-04
#
# Epoch 00010: val_loss improved from 0.00095 to 0.00087, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 3.9478e-04 - val_loss: 8.4465e-04
#
# Epoch 00011: val_loss improved from 0.00087 to 0.00084, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 3.6776e-04 - val_loss: 8.7130e-04
#
# Epoch 00012: val_loss did not improve from 0.00084
# Epoch 13/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 3.4983e-04 - val_loss: 8.0421e-04
#
# Epoch 00013: val_loss improved from 0.00084 to 0.00080, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 3.2875e-04 - val_loss: 7.7838e-04
#
# Epoch 00014: val_loss improved from 0.00080 to 0.00078, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 3.1980e-04 - val_loss: 7.5474e-04
#
# Epoch 00015: val_loss improved from 0.00078 to 0.00075, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 3.0186e-04 - val_loss: 7.5057e-04
#
# Epoch 00016: val_loss improved from 0.00075 to 0.00075, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 2.9663e-04 - val_loss: 7.3353e-04
#
# Epoch 00017: val_loss improved from 0.00075 to 0.00073, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 2.8220e-04 - val_loss: 7.3141e-04
#
# Epoch 00018: val_loss improved from 0.00073 to 0.00073, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 2.7413e-04 - val_loss: 7.1302e-04
#
# Epoch 00019: val_loss improved from 0.00073 to 0.00071, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 2.6340e-04 - val_loss: 7.1083e-04
#
# Epoch 00020: val_loss improved from 0.00071 to 0.00071, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 2.5858e-04 - val_loss: 7.2367e-04
#
# Epoch 00021: val_loss did not improve from 0.00071
# Epoch 22/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 2.4694e-04 - val_loss: 7.4084e-04
#
# Epoch 00022: val_loss did not improve from 0.00071
# Epoch 23/150
# 3424/3424 [==============================] - 1s 183us/step - loss: 2.4629e-04 - val_loss: 6.9341e-04
#
# Epoch 00023: val_loss improved from 0.00071 to 0.00069, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 2.3602e-04 - val_loss: 6.6586e-04
#
# Epoch 00024: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 2.3479e-04 - val_loss: 6.8113e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/150
# 3424/3424 [==============================] - 1s 183us/step - loss: 2.2581e-04 - val_loss: 6.8175e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 2.1741e-04 - val_loss: 7.1443e-04
#
# Epoch 00027: val_loss did not improve from 0.00067
# Epoch 28/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 2.2095e-04 - val_loss: 6.9112e-04
#
# Epoch 00028: val_loss did not improve from 0.00067
# Epoch 29/150
# 3424/3424 [==============================] - 1s 179us/step - loss: 2.1224e-04 - val_loss: 6.5996e-04
#
# Epoch 00029: val_loss improved from 0.00067 to 0.00066, saving model to best_weights_augment.h5
# Epoch 30/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 2.0915e-04 - val_loss: 6.5812e-04
#
# Epoch 00030: val_loss improved from 0.00066 to 0.00066, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 1s 184us/step - loss: 1.9933e-04 - val_loss: 6.6649e-04
#
# Epoch 00031: val_loss did not improve from 0.00066
# Epoch 32/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 1.9866e-04 - val_loss: 6.5140e-04
#
# Epoch 00032: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 182us/step - loss: 1.9291e-04 - val_loss: 6.6863e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.9028e-04 - val_loss: 6.5781e-04
#
# Epoch 00034: val_loss did not improve from 0.00065
# Epoch 35/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 1.8743e-04 - val_loss: 6.7193e-04
#
# Epoch 00035: val_loss did not improve from 0.00065
# Epoch 36/150
# 3424/3424 [==============================] - 1s 196us/step - loss: 1.8126e-04 - val_loss: 6.4675e-04
#
# Epoch 00036: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 37/150
# 3424/3424 [==============================] - 1s 179us/step - loss: 1.8039e-04 - val_loss: 6.6425e-04
#
# Epoch 00037: val_loss did not improve from 0.00065
# Epoch 38/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.8050e-04 - val_loss: 6.5136e-04
#
# Epoch 00038: val_loss did not improve from 0.00065
# Epoch 39/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 1.7438e-04 - val_loss: 6.6465e-04
#
# Epoch 00039: val_loss did not improve from 0.00065
# Epoch 40/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 1.7615e-04 - val_loss: 6.8583e-04
#
# Epoch 00040: val_loss did not improve from 0.00065
# Epoch 41/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.7354e-04 - val_loss: 6.2998e-04
#
# Epoch 00041: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 1s 179us/step - loss: 1.6723e-04 - val_loss: 6.7989e-04
#
# Epoch 00042: val_loss did not improve from 0.00063
# Epoch 43/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.6392e-04 - val_loss: 6.6897e-04
#
# Epoch 00043: val_loss did not improve from 0.00063
# Epoch 44/150
# 3424/3424 [==============================] - 1s 187us/step - loss: 1.6205e-04 - val_loss: 6.5364e-04
#
# Epoch 00044: val_loss did not improve from 0.00063
# Epoch 45/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.6018e-04 - val_loss: 6.5832e-04
#
# Epoch 00045: val_loss did not improve from 0.00063
# Epoch 46/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.6118e-04 - val_loss: 6.5767e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.5885e-04 - val_loss: 6.3491e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 1.5615e-04 - val_loss: 6.3842e-04
#
# Epoch 00048: val_loss did not improve from 0.00063
# Epoch 49/150
# 3424/3424 [==============================] - 1s 182us/step - loss: 1.5318e-04 - val_loss: 6.2750e-04
#
# Epoch 00049: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 50/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.4824e-04 - val_loss: 6.6092e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.4399e-04 - val_loss: 6.4296e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 1.4184e-04 - val_loss: 6.3445e-04
#
# Epoch 00052: val_loss did not improve from 0.00063
# Epoch 53/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.4433e-04 - val_loss: 6.6209e-04
#
# Epoch 00053: val_loss did not improve from 0.00063
# Epoch 54/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 1.4675e-04 - val_loss: 6.3796e-04
#
# Epoch 00054: val_loss did not improve from 0.00063
# Epoch 55/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.4111e-04 - val_loss: 6.3839e-04
#
# Epoch 00055: val_loss did not improve from 0.00063
# Epoch 56/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 1.3477e-04 - val_loss: 6.4667e-04
#
# Epoch 00056: val_loss did not improve from 0.00063
# Epoch 57/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.3394e-04 - val_loss: 6.3054e-04
#
# Epoch 00057: val_loss did not improve from 0.00063
# Epoch 58/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.3436e-04 - val_loss: 6.5078e-04
#
# Epoch 00058: val_loss did not improve from 0.00063
# Epoch 59/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.3059e-04 - val_loss: 6.3824e-04
#
# Epoch 00059: val_loss did not improve from 0.00063
# Epoch 60/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 1.3215e-04 - val_loss: 6.2233e-04
#
# Epoch 00060: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 61/150
# 3424/3424 [==============================] - 1s 184us/step - loss: 1.2917e-04 - val_loss: 6.6095e-04
#
# Epoch 00061: val_loss did not improve from 0.00062
# Epoch 62/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.2948e-04 - val_loss: 6.5012e-04
#
# Epoch 00062: val_loss did not improve from 0.00062
# Epoch 63/150
# 3424/3424 [==============================] - 1s 192us/step - loss: 1.2701e-04 - val_loss: 6.2247e-04
#
# Epoch 00063: val_loss did not improve from 0.00062
# Epoch 64/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 1.2558e-04 - val_loss: 6.3353e-04
#
# Epoch 00064: val_loss did not improve from 0.00062
# Epoch 65/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.2291e-04 - val_loss: 6.6762e-04
#
# Epoch 00065: val_loss did not improve from 0.00062
# Epoch 66/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.2387e-04 - val_loss: 6.2258e-04
#
# Epoch 00066: val_loss did not improve from 0.00062
# Epoch 67/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.2306e-04 - val_loss: 6.4186e-04
#
# Epoch 00067: val_loss did not improve from 0.00062
# Epoch 68/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.2035e-04 - val_loss: 6.5147e-04
#
# Epoch 00068: val_loss did not improve from 0.00062
# Epoch 69/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.1869e-04 - val_loss: 6.2996e-04
#
# Epoch 00069: val_loss did not improve from 0.00062
# Epoch 70/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 1.1817e-04 - val_loss: 6.4585e-04
#
# Epoch 00070: val_loss did not improve from 0.00062
# Epoch 71/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.1812e-04 - val_loss: 6.5022e-04
#
# Epoch 00071: val_loss did not improve from 0.00062
# Epoch 72/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 1.1446e-04 - val_loss: 6.0988e-04
#
# Epoch 00072: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 73/150
# 3424/3424 [==============================] - 1s 179us/step - loss: 1.1648e-04 - val_loss: 6.4935e-04
#
# Epoch 00073: val_loss did not improve from 0.00061
# Epoch 74/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.1508e-04 - val_loss: 6.3204e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 1s 183us/step - loss: 1.1526e-04 - val_loss: 6.4984e-04
#
# Epoch 00075: val_loss did not improve from 0.00061
# Epoch 76/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.1283e-04 - val_loss: 6.4986e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 1s 179us/step - loss: 1.1234e-04 - val_loss: 6.4587e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.1134e-04 - val_loss: 6.3075e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.0885e-04 - val_loss: 6.3319e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.0731e-04 - val_loss: 6.4405e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 1s 183us/step - loss: 1.0938e-04 - val_loss: 6.5348e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 1s 184us/step - loss: 1.0710e-04 - val_loss: 6.2374e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 1s 182us/step - loss: 1.0597e-04 - val_loss: 6.3707e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.0379e-04 - val_loss: 6.7070e-04
#
# Epoch 00084: val_loss did not improve from 0.00061
# Epoch 85/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 1.0477e-04 - val_loss: 6.5749e-04
#
# Epoch 00085: val_loss did not improve from 0.00061
# Epoch 86/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.0838e-04 - val_loss: 6.4801e-04
#
# Epoch 00086: val_loss did not improve from 0.00061
# Epoch 87/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.0927e-04 - val_loss: 6.3028e-04
#
# Epoch 00087: val_loss did not improve from 0.00061
# Epoch 88/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.0225e-04 - val_loss: 6.2686e-04
#
# Epoch 00088: val_loss did not improve from 0.00061
# Epoch 89/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 1.0209e-04 - val_loss: 6.2822e-04
#
# Epoch 00089: val_loss did not improve from 0.00061
# Epoch 90/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0021e-04 - val_loss: 6.2723e-04
#
# Epoch 00090: val_loss did not improve from 0.00061
# Epoch 91/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.8233e-05 - val_loss: 6.3405e-04
#
# Epoch 00091: val_loss did not improve from 0.00061
# Epoch 92/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 9.9452e-05 - val_loss: 6.7023e-04
#
# Epoch 00092: val_loss did not improve from 0.00061
# Epoch 93/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 9.9584e-05 - val_loss: 6.1484e-04
#
# Epoch 00093: val_loss did not improve from 0.00061
# Epoch 94/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 9.9040e-05 - val_loss: 6.3361e-04
#
# Epoch 00094: val_loss did not improve from 0.00061
# Epoch 95/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.7104e-05 - val_loss: 6.3323e-04
#
# Epoch 00095: val_loss did not improve from 0.00061
# Epoch 96/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 9.5214e-05 - val_loss: 6.2474e-04
#
# Epoch 00096: val_loss did not improve from 0.00061
# Epoch 97/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.7444e-05 - val_loss: 6.4390e-04
#
# Epoch 00097: val_loss did not improve from 0.00061
# Epoch 98/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 9.5351e-05 - val_loss: 6.3136e-04
#
# Epoch 00098: val_loss did not improve from 0.00061
# Epoch 99/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 9.4966e-05 - val_loss: 6.2868e-04
#
# Epoch 00099: val_loss did not improve from 0.00061
# Epoch 100/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 9.5666e-05 - val_loss: 6.2440e-04
#
# Epoch 00100: val_loss did not improve from 0.00061
# Epoch 101/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 9.5111e-05 - val_loss: 6.2183e-04
#
# Epoch 00101: val_loss did not improve from 0.00061
# Epoch 102/150
# 3424/3424 [==============================] - 1s 186us/step - loss: 9.6357e-05 - val_loss: 6.2088e-04
#
# Epoch 00102: val_loss did not improve from 0.00061
# Epoch 103/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 9.5427e-05 - val_loss: 6.1842e-04
#
# Epoch 00103: val_loss did not improve from 0.00061
# Epoch 104/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 9.6337e-05 - val_loss: 6.2600e-04
#
# Epoch 00104: val_loss did not improve from 0.00061
# Epoch 105/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.5103e-05 - val_loss: 6.1884e-04
#
# Epoch 00105: val_loss did not improve from 0.00061
# Epoch 106/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.4898e-05 - val_loss: 6.4077e-04
#
# Epoch 00106: val_loss did not improve from 0.00061
# Epoch 107/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.4533e-05 - val_loss: 6.5128e-04
#
# Epoch 00107: val_loss did not improve from 0.00061
# Epoch 108/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 9.1579e-05 - val_loss: 6.4714e-04
#
# Epoch 00108: val_loss did not improve from 0.00061
# Epoch 109/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 9.6176e-05 - val_loss: 6.1204e-04
#
# Epoch 00109: val_loss did not improve from 0.00061
# Epoch 110/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 9.0578e-05 - val_loss: 6.1266e-04
#
# Epoch 00110: val_loss did not improve from 0.00061
# Epoch 111/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.4730e-05 - val_loss: 6.5528e-04
#
# Epoch 00111: val_loss did not improve from 0.00061
# Epoch 112/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.0886e-05 - val_loss: 6.5259e-04
#
# Epoch 00112: val_loss did not improve from 0.00061
# Epoch 113/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 8.8468e-05 - val_loss: 6.3132e-04
#
# Epoch 00113: val_loss did not improve from 0.00061
# Epoch 114/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.7945e-05 - val_loss: 6.1691e-04
#
# Epoch 00114: val_loss did not improve from 0.00061
# Epoch 115/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.8561e-05 - val_loss: 6.2161e-04
#
# Epoch 00115: val_loss did not improve from 0.00061
# Epoch 116/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.9203e-05 - val_loss: 6.2159e-04
#
# Epoch 00116: val_loss did not improve from 0.00061
# Epoch 117/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 8.8681e-05 - val_loss: 6.1329e-04
#
# Epoch 00117: val_loss did not improve from 0.00061
# Epoch 118/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 8.8670e-05 - val_loss: 6.2597e-04
#
# Epoch 00118: val_loss did not improve from 0.00061
# Epoch 119/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.8338e-05 - val_loss: 6.0940e-04
#
# Epoch 00119: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 120/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 8.6595e-05 - val_loss: 6.4585e-04
#
# Epoch 00120: val_loss did not improve from 0.00061
# Epoch 121/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 8.6275e-05 - val_loss: 6.3929e-04
#
# Epoch 00121: val_loss did not improve from 0.00061
# Epoch 122/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 8.5668e-05 - val_loss: 6.2435e-04
#
# Epoch 00122: val_loss did not improve from 0.00061
# Epoch 123/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 8.5696e-05 - val_loss: 6.2733e-04
#
# Epoch 00123: val_loss did not improve from 0.00061
# Epoch 124/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 8.5978e-05 - val_loss: 6.0697e-04
#
# Epoch 00124: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 125/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.5908e-05 - val_loss: 6.3692e-04
#
# Epoch 00125: val_loss did not improve from 0.00061
# Epoch 126/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.4917e-05 - val_loss: 6.4177e-04
#
# Epoch 00126: val_loss did not improve from 0.00061
# Epoch 127/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.8580e-05 - val_loss: 6.2893e-04
#
# Epoch 00127: val_loss did not improve from 0.00061
# Epoch 128/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.8449e-05 - val_loss: 6.0587e-04
#
# Epoch 00128: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 129/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 9.0130e-05 - val_loss: 6.2495e-04
#
# Epoch 00129: val_loss did not improve from 0.00061
# Epoch 130/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 8.5515e-05 - val_loss: 6.1295e-04
#
# Epoch 00130: val_loss did not improve from 0.00061
# Epoch 131/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.5822e-05 - val_loss: 6.3467e-04
#
# Epoch 00131: val_loss did not improve from 0.00061
# Epoch 132/150
# 3424/3424 [==============================] - 1s 194us/step - loss: 8.3427e-05 - val_loss: 6.3057e-04
#
# Epoch 00132: val_loss did not improve from 0.00061
# Epoch 133/150
# 3424/3424 [==============================] - 1s 189us/step - loss: 8.4596e-05 - val_loss: 6.1837e-04
#
# Epoch 00133: val_loss did not improve from 0.00061
# Epoch 134/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.7300e-05 - val_loss: 6.2309e-04
#
# Epoch 00134: val_loss did not improve from 0.00061
# Epoch 135/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.4658e-05 - val_loss: 6.2202e-04
#
# Epoch 00135: val_loss did not improve from 0.00061
# Epoch 136/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.2657e-05 - val_loss: 6.2246e-04
#
# Epoch 00136: val_loss did not improve from 0.00061
# Epoch 137/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 8.3796e-05 - val_loss: 6.3026e-04
#
# Epoch 00137: val_loss did not improve from 0.00061
# Epoch 138/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 8.1484e-05 - val_loss: 6.3342e-04
#
# Epoch 00138: val_loss did not improve from 0.00061
# Epoch 139/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.3106e-05 - val_loss: 6.3668e-04
#
# Epoch 00139: val_loss did not improve from 0.00061
# Epoch 140/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 8.5316e-05 - val_loss: 6.2635e-04
#
# Epoch 00140: val_loss did not improve from 0.00061
# Epoch 141/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 8.6977e-05 - val_loss: 6.4542e-04
#
# Epoch 00141: val_loss did not improve from 0.00061
# Epoch 142/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.4442e-05 - val_loss: 6.4454e-04
#
# Epoch 00142: val_loss did not improve from 0.00061
# Epoch 143/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.1148e-05 - val_loss: 6.3941e-04
#
# Epoch 00143: val_loss did not improve from 0.00061
# Epoch 144/150
# 3424/3424 [==============================] - 1s 186us/step - loss: 7.9670e-05 - val_loss: 6.3678e-04
#
# Epoch 00144: val_loss did not improve from 0.00061
# Epoch 145/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.0480e-05 - val_loss: 6.5806e-04
#
# Epoch 00145: val_loss did not improve from 0.00061
# Epoch 146/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.2642e-05 - val_loss: 6.3097e-04
#
# Epoch 00146: val_loss did not improve from 0.00061
# Epoch 147/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.1181e-05 - val_loss: 6.5043e-04
#
# Epoch 00147: val_loss did not improve from 0.00061
# Epoch 148/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 8.0163e-05 - val_loss: 6.3021e-04
#
# Epoch 00148: val_loss did not improve from 0.00061
# Epoch 149/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.0257e-05 - val_loss: 6.4131e-04
#
# Epoch 00149: val_loss did not improve from 0.00061
# Epoch 150/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 8.1052e-05 - val_loss: 6.2836e-04
#
# Epoch 00150: val_loss did not improve from 0.00061

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
